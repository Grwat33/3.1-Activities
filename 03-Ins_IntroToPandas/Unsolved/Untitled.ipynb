# %%
import pandas as pd

# %%
data_series = pd.Series(['UNC', 'Duke', 'NC State'])

# %%
data_series
# Out:
# 0         UNC
# 1        Duke
# 2    NC State
# dtype: object

# %%
data_series[1]
# Out:
# 'Duke'

# %%
college_dicts =[
    {
        'name': 'UNC',
        'students': 10000,
        "is_state_school": True
    },
    {
        'name': 'Duke',
        'students': 5000,
        "is_state_school": False

    },
    {
        'name': 'NC State',
        'students': 20000,
        "is_state_school": True
    },
        {
        'name': 'Meredith',
        'students': 1000,
        "is_state_school": False
    },
    {
        'name': 'Peace',
        'students': 2000,
        "is_state_school": False
    },
    {
        'name': 'UNC Charlotte',
        'students': 20000,
        "is_state_school":True
    },
]

college_dicts
# Out:
# [{'name': 'UNC', 'students': 10000, 'is_state_school': True},
#  {'name': 'Duke', 'students': 5000, 'is_state_school': False},
#  {'name': 'NC State', 'students': 20000, 'is_state_school': True},
#  {'name': 'Meredith', 'students': 1000, 'is_state_school': False},
#  {'name': 'Peace', 'students': 2000, 'is_state_school': False},
#  {'name': 'UNC Charlotte', 'students': 20000, 'is_state_school': True}]

# %%
colleges_df = pd.DataFrame(college_dicts)

# %%
colleges_df
# Out:
#        name  students
# 0       UNC     10000
# 1      Duke      5000
# 2  NC State     20000

# %%
college_lists = {
    'name': ['UNC', 'Duke', 'NC State'],
    'students': [10000, 5000, 2000]
}

# %%
college_lists
# Out:
# {'name': ['UNC', 'Duke', 'NC State'], 'students': [10000, 5000, 2000]}

# %%
colleges_df = pd.DataFrame(college_lists)

# %%
colleges_df
# Out:
#        name  students
# 0       UNC     10000
# 1      Duke      5000
# 2  NC State      2000

# %%
colleges_df.head()
# Out:
#        name  students
# 0       UNC     10000
# 1      Duke      5000
# 2  NC State      2000

# %%
colleges_df.head()
# Out:
#        name  students  is_state_school
# 0       UNC     10000             True
# 1      Duke      5000            False
# 2  NC State     20000             True
# 3  Meredith      1000            False
# 4     Peace      2000            False

# %%
colleges_df.describe()
# Out:
#            students
# count      6.000000
# mean    9666.666667
# std     8594.571930
# min     1000.000000
# 25%     2750.000000
# 50%     7500.000000
# 75%    17500.000000
# max    20000.000000

# %%
colleges_df['name']
# Out:
# 0              UNC
# 1             Duke
# 2         NC State
# 3         Meredith
# 4            Peace
# 5    UNC Charlotte
# Name: name, dtype: object

# %%
colleges_df[['name', 'is_state_school']]
# Out:
#             name  is_state_school
# 0            UNC             True
# 1           Duke            False
# 2       NC State             True
# 3       Meredith            False
# 4          Peace            False
# 5  UNC Charlotte             True

# %%
colleges_df['students'].mean()
# Out:
# 9666.666666666666

# %%
colleges_df['students'].sum()
# Out:
# 58000

# %%
college_names = colleges_df['name'].unique()

# %%
for name in college_names:
    print(name)
# Out:
# UNC
# Duke
# NC State
# Meredith
# Peace
# UNC Charlotte

# %%
colleges_df
# Out:
#             name  students  is_state_school
# 0            UNC     10000             True
# 1           Duke      5000            False
# 2       NC State     20000             True
# 3       Meredith      1000            False
# 4          Peace      2000            False
# 5  UNC Charlotte     20000             True

# %%
students_in_thousands = colleges_df['students'] / 1000
students_in_thousands
# Out:
# 0    10.0
# 1     5.0
# 2    20.0
# 3     1.0
# 4     2.0
# 5    20.0
# Name: students, dtype: float64

# %%
colleges_df['students in thousands'] = students_in_thousands

# %%
colleges_df
# Out:
#             name  students  is_state_school
# 0            UNC     10000             True
# 1           Duke      5000            False
# 2       NC State     20000             True
# 3       Meredith      1000            False
# 4          Peace      2000            False
# 5  UNC Charlotte     20000             True

# %%
colleges_df.drop(columns=['students in thousands'], inplace=True)
